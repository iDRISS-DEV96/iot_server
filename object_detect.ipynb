# %% [markdown]
# <a href="https://colab.research.google.com/github/iDRISS-DEV96/iot_server/blob/master/object_detect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# YOLO v3
import os

import scipy.io
import scipy.misc
import numpy as np
import pandas as pd
import PIL
import struct
import cv2
from numpy import expand_dims
import tensorflow as tf
from skimage.transform import resize
from keras import backend as K
from keras.layers import Input, Lambda, Conv2D, BatchNormalization, LeakyReLU, ZeroPadding2D, UpSampling2D
from keras.models import load_model, Model
from tensorflow.keras.layers import add, concatenate
from tensorflow.keras.utils import load_img,img_to_array
# from keras.preprocessing.image import img_to_array
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from matplotlib.patches import Rectangle

# %matplotlib inline

# %%
class WeightReader:
    def __init__(self, weight_file):
        with open(weight_file, 'rb') as w_f:
            major,    = struct.unpack('i', w_f.read(4))
            minor,    = struct.unpack('i', w_f.read(4))
            revision, = struct.unpack('i', w_f.read(4))

            if (major*10 + minor) >= 2 and major < 1000 and minor < 1000:
                w_f.read(8)
            else:
                w_f.read(4)

            transpose = (major > 1000) or (minor > 1000)
            
            binary = w_f.read()

        self.offset = 0
        self.all_weights = np.frombuffer(binary, dtype='float32')
        
    def read_bytes(self, size):
        self.offset = self.offset + size
        return self.all_weights[self.offset-size:self.offset]

    def load_weights(self, model):
        for i in range(106):
            try:
                conv_layer = model.get_layer('conv_' + str(i))
                print("loading weights of convolution #" + str(i))

                if i not in [81, 93, 105]:
                    norm_layer = model.get_layer('bnorm_' + str(i))

                    size = np.prod(norm_layer.get_weights()[0].shape)

                    beta  = self.read_bytes(size) # bias
                    gamma = self.read_bytes(size) # scale
                    mean  = self.read_bytes(size) # mean
                    var   = self.read_bytes(size) # variance            

                    weights = norm_layer.set_weights([gamma, beta, mean, var])  

                if len(conv_layer.get_weights()) > 1:
                    bias   = self.read_bytes(np.prod(conv_layer.get_weights()[1].shape))
                    kernel = self.read_bytes(np.prod(conv_layer.get_weights()[0].shape))
                    
                    kernel = kernel.reshape(list(reversed(conv_layer.get_weights()[0].shape)))
                    kernel = kernel.transpose([2,3,1,0])
                    conv_layer.set_weights([kernel, bias])
                else:
                    kernel = self.read_bytes(np.prod(conv_layer.get_weights()[0].shape))
                    kernel = kernel.reshape(list(reversed(conv_layer.get_weights()[0].shape)))
                    kernel = kernel.transpose([2,3,1,0])
                    conv_layer.set_weights([kernel])
            except ValueError:
                print("no convolution #" + str(i))     
    
    def reset(self):
        self.offset = 0

# %%
def _conv_block(inp, convs, skip=True):
    x = inp
    count = 0
    
    for conv in convs:
        if count == (len(convs) - 2) and skip:
            skip_connection = x
        count += 1
        
        if conv['stride'] > 1: x = ZeroPadding2D(((1,0),(1,0)))(x) # peculiar padding as darknet prefer left and top
        x = Conv2D(conv['filter'], 
                   conv['kernel'], 
                   strides=conv['stride'], 
                   padding='valid' if conv['stride'] > 1 else 'same', # peculiar padding as darknet prefer left and top
                   name='conv_' + str(conv['layer_idx']), 
                   use_bias=False if conv['bnorm'] else True)(x)
        if conv['bnorm']: x = BatchNormalization(epsilon=0.001, name='bnorm_' + str(conv['layer_idx']))(x)
        if conv['leaky']: x = LeakyReLU(alpha=0.1, name='leaky_' + str(conv['layer_idx']))(x)

    return add([skip_connection, x]) if skip else x

# %%
# creating the YOLO model
def make_yolov3_model():
    input_image = Input(shape=(None, None, 3))

    # Layer  0 => 4
    x = _conv_block(input_image, [{'filter': 32, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 0},
                                  {'filter': 64, 'kernel': 3, 'stride': 2, 'bnorm': True, 'leaky': True, 'layer_idx': 1},
                                  {'filter': 32, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 2},
                                  {'filter': 64, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 3}])

    # Layer  5 => 8
    x = _conv_block(x, [{'filter': 128, 'kernel': 3, 'stride': 2, 'bnorm': True, 'leaky': True, 'layer_idx': 5},
                        {'filter':  64, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 6},
                        {'filter': 128, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 7}])

    # Layer  9 => 11
    x = _conv_block(x, [{'filter':  64, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 9},
                        {'filter': 128, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 10}])

    # Layer 12 => 15
    x = _conv_block(x, [{'filter': 256, 'kernel': 3, 'stride': 2, 'bnorm': True, 'leaky': True, 'layer_idx': 12},
                        {'filter': 128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 13},
                        {'filter': 256, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 14}])

    # Layer 16 => 36
    for i in range(7):
        x = _conv_block(x, [{'filter': 128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 16+i*3},
                            {'filter': 256, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 17+i*3}])
        
    skip_36 = x
        
    # Layer 37 => 40
    x = _conv_block(x, [{'filter': 512, 'kernel': 3, 'stride': 2, 'bnorm': True, 'leaky': True, 'layer_idx': 37},
                        {'filter': 256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 38},
                        {'filter': 512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 39}])

    # Layer 41 => 61
    for i in range(7):
        x = _conv_block(x, [{'filter': 256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 41+i*3},
                            {'filter': 512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 42+i*3}])
        
    skip_61 = x
        
    # Layer 62 => 65
    x = _conv_block(x, [{'filter': 1024, 'kernel': 3, 'stride': 2, 'bnorm': True, 'leaky': True, 'layer_idx': 62},
                        {'filter':  512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 63},
                        {'filter': 1024, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 64}])

    # Layer 66 => 74
    for i in range(3):
        x = _conv_block(x, [{'filter':  512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 66+i*3},
                            {'filter': 1024, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 67+i*3}])
        
    # Layer 75 => 79
    x = _conv_block(x, [{'filter':  512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 75},
                        {'filter': 1024, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 76},
                        {'filter':  512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 77},
                        {'filter': 1024, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 78},
                        {'filter':  512, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 79}], skip=False)

    # Layer 80 => 82
    yolo_82 = _conv_block(x, [{'filter': 1024, 'kernel': 3, 'stride': 1, 'bnorm': True,  'leaky': True,  'layer_idx': 80},
                              {'filter':  255, 'kernel': 1, 'stride': 1, 'bnorm': False, 'leaky': False, 'layer_idx': 81}], skip=False)

    # Layer 83 => 86
    x = _conv_block(x, [{'filter': 256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 84}], skip=False)
    x = UpSampling2D(2)(x)
    x = concatenate([x, skip_61])

    # Layer 87 => 91
    x = _conv_block(x, [{'filter': 256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 87},
                        {'filter': 512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 88},
                        {'filter': 256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 89},
                        {'filter': 512, 'kernel': 3, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 90},
                        {'filter': 256, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True, 'layer_idx': 91}], skip=False)

    # Layer 92 => 94
    yolo_94 = _conv_block(x, [{'filter': 512, 'kernel': 3, 'stride': 1, 'bnorm': True,  'leaky': True,  'layer_idx': 92},
                              {'filter': 255, 'kernel': 1, 'stride': 1, 'bnorm': False, 'leaky': False, 'layer_idx': 93}], skip=False)

    # Layer 95 => 98
    x = _conv_block(x, [{'filter': 128, 'kernel': 1, 'stride': 1, 'bnorm': True, 'leaky': True,   'layer_idx': 96}], skip=False)
    x = UpSampling2D(2)(x)
    x = concatenate([x, skip_36])

    # Layer 99 => 106
    yolo_106 = _conv_block(x, [{'filter': 128, 'kernel': 1, 'stride': 1, 'bnorm': True,  'leaky': True,  'layer_idx': 99},
                               {'filter': 256, 'kernel': 3, 'stride': 1, 'bnorm': True,  'leaky': True,  'layer_idx': 100},
                               {'filter': 128, 'kernel': 1, 'stride': 1, 'bnorm': True,  'leaky': True,  'layer_idx': 101},
                               {'filter': 256, 'kernel': 3, 'stride': 1, 'bnorm': True,  'leaky': True,  'layer_idx': 102},
                               {'filter': 128, 'kernel': 1, 'stride': 1, 'bnorm': True,  'leaky': True,  'layer_idx': 103},
                               {'filter': 256, 'kernel': 3, 'stride': 1, 'bnorm': True,  'leaky': True,  'layer_idx': 104},
                               {'filter': 255, 'kernel': 1, 'stride': 1, 'bnorm': False, 'leaky': False, 'layer_idx': 105}], skip=False)

    model = Model(input_image, [yolo_82, yolo_94, yolo_106])    
    return model

# %%
! wget -c https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2022-12-15 15:56:18--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  17.5MB/s    in 16s
#
# 2022-12-15 15:56:35 (14.9 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
net_h, net_w = 416, 416
obj_thresh, nms_thresh = 0.5, 0.45
anchors = [[116,90,  156,198,  373,326],  [30,61, 62,45,  59,119], [10,13,  16,30,  33,23]]
labels = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", \
              "boat", "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", \
              "bird", "cat", "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", \
              "backpack", "umbrella", "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", \
              "sports ball", "kite", "baseball bat", "baseball glove", "skateboard", "surfboard", \
              "tennis racket", "bottle", "wine glass", "cup", "fork", "knife", "spoon", "bowl", "banana", \
              "apple", "sandwich", "orange", "broccoli", "carrot", "hot dog", "pizza", "donut", "cake", \
              "chair", "sofa", "pottedplant", "bed", "diningtable", "toilet", "tvmonitor", "laptop", "mouse", \
              "remote", "keyboard", "cell phone", "microwave", "oven", "toaster", "sink", "refrigerator", \
              "book", "clock", "vase", "scissors", "teddy bear", "hair drier", "toothbrush"]

# make the yolov3 model to predict 80 classes on COCO

yolov3 = make_yolov3_model()


# load the weights trained on COCO into the model
weight_reader = WeightReader('yolov3.weights')
weight_reader.load_weights(yolov3)
# Out:
# loading weights of convolution #0
# loading weights of convolution #1
# loading weights of convolution #2
# loading weights of convolution #3
# no convolution #4
# loading weights of convolution #5
# loading weights of convolution #6
# loading weights of convolution #7
# no convolution #8
# loading weights of convolution #9
# loading weights of convolution #10
# no convolution #11
# loading weights of convolution #12
# loading weights of convolution #13
# loading weights of convolution #14
# no convolution #15
# loading weights of convolution #16
# loading weights of convolution #17
# no convolution #18
# loading weights of convolution #19
# loading weights of convolution #20
# no convolution #21
# loading weights of convolution #22
# loading weights of convolution #23
# no convolution #24
# loading weights of convolution #25
# loading weights of convolution #26
# no convolution #27
# loading weights of convolution #28
# loading weights of convolution #29
# no convolution #30
# loading weights of convolution #31
# loading weights of convolution #32
# no convolution #33
# loading weights of convolution #34
# loading weights of convolution #35
# no convolution #36
# loading weights of convolution #37
# loading weights of convolution #38
# loading weights of convolution #39
# no convolution #40
# loading weights of convolution #41
# loading weights of convolution #42
# no convolution #43
# loading weights of convolution #44
# loading weights of convolution #45
# no convolution #46
# loading weights of convolution #47
# loading weights of convolution #48
# no convolution #49
# loading weights of convolution #50
# loading weights of convolution #51
# no convolution #52
# loading weights of convolution #53
# loading weights of convolution #54
# no convolution #55
# loading weights of convolution #56
# loading weights of convolution #57
# no convolution #58
# loading weights of convolution #59
# loading weights of convolution #60
# no convolution #61
# loading weights of convolution #62
# loading weights of convolution #63
# loading weights of convolution #64
# no convolution #65
# loading weights of convolution #66
# loading weights of convolution #67
# no convolution #68
# loading weights of convolution #69
# loading weights of convolution #70
# no convolution #71
# loading weights of convolution #72
# loading weights of convolution #73
# no convolution #74
# loading weights of convolution #75
# loading weights of convolution #76
# loading weights of convolution #77
# loading weights of convolution #78
# loading weights of convolution #79
# loading weights of convolution #80
# loading weights of convolution #81
# no convolution #82
# no convolution #83
# loading weights of convolution #84
# no convolution #85
# no convolution #86
# loading weights of convolution #87
# loading weights of convolution #88
# loading weights of convolution #89
# loading weights of convolution #90
# loading weights of convolution #91
# loading weights of convolution #92
# loading weights of convolution #93
# no convolution #94
# no convolution #95
# loading weights of convolution #96
# no convolution #97
# no convolution #98
# loading weights of convolution #99
# loading weights of convolution #100
# loading weights of convolution #101
# loading weights of convolution #102
# loading weights of convolution #103
# loading weights of convolution #104
# loading weights of convolution #105

# %%
# save the model to file
yolov3.save('yolov3.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# load yolov3 model
yolov3 = load_model('yolov3.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
from numpy import expand_dims
def load_image_pixels(filename, shape):
    # load the image to get its shape
    image = load_img(filename)
    width, height = image.size
    # load the image with the required size
    image = load_img(filename, target_size=shape)
    # convert to numpy array
    image = img_to_array(image)
    # scale pixel values to [0, 1]
    image = image.astype('float32')
    image /= 255.0
    # add a dimension so that we have one sample
    image = expand_dims(image, 0)
    return image, width, height

# %%
! wget -c https://images.unsplash.com/photo-1533090368676-1fd25485db88
# Out:
# --2022-12-15 16:32:56--  https://images.unsplash.com/photo-1533090368676-1fd25485db88
# Resolving images.unsplash.com (images.unsplash.com)... 199.232.46.208, 2a04:4e42:48::720
# Connecting to images.unsplash.com (images.unsplash.com)|199.232.46.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 764305 (746K) [image/jpeg]
# Saving to: ‘photo-1533090368676-1fd25485db88’
#
# photo-1533090368676 100%[===================>] 746.39K  --.-KB/s    in 0.005s
#
# 2022-12-15 16:32:56 (138 MB/s) - ‘photo-1533090368676-1fd25485db88’ saved [764305/764305]

# %%
# define the expected input shape for the model
input_w, input_h = 416, 416
# define our new photo
photo_filename = 'photo-1533090368676-1fd25485db88'
# load and prepare image
image, image_w, image_h = load_image_pixels(photo_filename, (input_w, input_h))

# %%
class BoundBox:
    def __init__(self, xmin, ymin, xmax, ymax, objness = None, classes = None):
        self.xmin = xmin
        self.ymin = ymin
        self.xmax = xmax
        self.ymax = ymax
        
        self.objness = objness
        self.classes = classes

        self.label = -1
        self.score = -1

    def get_label(self):
        if self.label == -1:
            self.label = np.argmax(self.classes)
        
        return self.label
    
    def get_score(self):
        if self.score == -1:
            self.score = self.classes[self.get_label()]
            
        return self.score

def _sigmoid(x):
    return 1. / (1. + np.exp(-x))

def _interval_overlap(interval_a, interval_b):
    x1, x2 = interval_a
    x3, x4 = interval_b

    if x3 < x1:
        if x4 < x1:
            return 0
        else:
            return min(x2,x4) - x1
    else:
        if x2 < x3:
             return 0
        else:
            return min(x2,x4) - x3 
def bbox_iou(box1, box2):
    intersect_w = _interval_overlap([box1.xmin, box1.xmax], [box2.xmin, box2.xmax])
    intersect_h = _interval_overlap([box1.ymin, box1.ymax], [box2.ymin, box2.ymax])
    
    intersect = intersect_w * intersect_h

    w1, h1 = box1.xmax-box1.xmin, box1.ymax-box1.ymin
    w2, h2 = box2.xmax-box2.xmin, box2.ymax-box2.ymin
    
    union = w1*h1 + w2*h2 - intersect
    
    return float(intersect) / union

def do_nms(boxes, nms_thresh):
    if len(boxes) > 0:
        nb_class = len(boxes[0].classes)
    else:
        return
        
    for c in range(nb_class):
        sorted_indices = np.argsort([-box.classes[c] for box in boxes])

        for i in range(len(sorted_indices)):
            index_i = sorted_indices[i]

            if boxes[index_i].classes[c] == 0: continue

            for j in range(i+1, len(sorted_indices)):
                index_j = sorted_indices[j]

                if bbox_iou(boxes[index_i], boxes[index_j]) >= nms_thresh:
                    boxes[index_j].classes[c] = 0

# %%
#decode_netout() that will take each one of the NumPy arrays, one at a time, 
#and decode the candidate bounding boxes and class predictions
def decode_netout(netout, anchors, obj_thresh,  net_h, net_w):
    grid_h, grid_w = netout.shape[:2]
    nb_box = 3
    netout = netout.reshape((grid_h, grid_w, nb_box, -1))
    nb_class = netout.shape[-1] - 5

    boxes = []

    netout[..., :2]  = _sigmoid(netout[..., :2])
    netout[..., 4:]  = _sigmoid(netout[..., 4:])
    netout[..., 5:]  = netout[..., 4][..., np.newaxis] * netout[..., 5:]
    netout[..., 5:] *= netout[..., 5:] > obj_thresh

    for i in range(grid_h*grid_w):
        row = i / grid_w
        col = i % grid_w
        
        for b in range(nb_box):
            # 4th element is objectness score
            objectness = netout[int(row)][int(col)][b][4]
            #objectness = netout[..., :4]
            
            if(objectness.all() <= obj_thresh): continue
            
            # first 4 elements are x, y, w, and h
            x, y, w, h = netout[int(row)][int(col)][b][:4]

            x = (col + x) / grid_w # center position, unit: image width
            y = (row + y) / grid_h # center position, unit: image height
            w = anchors[2 * b + 0] * np.exp(w) / net_w # unit: image width
            h = anchors[2 * b + 1] * np.exp(h) / net_h # unit: image height  
            
            # last elements are class probabilities
            classes = netout[int(row)][col][b][5:]
            
            box = BoundBox(x-w/2, y-h/2, x+w/2, y+h/2, objectness, classes)
            #box = BoundBox(x-w/2, y-h/2, x+w/2, y+h/2, None, classes)

            boxes.append(box)

    return boxes

# %%
# bounding boxes will be stretched back into the shape of the original image
#will allow plotting the original image and draw the bounding boxes, hopefully detecting real objects.
# correct the sizes of the bounding boxes for the shape of the image
#correct_yolo_boxes(boxes, image_h, image_w, input_h, input_w)
def correct_yolo_boxes(boxes, image_h, image_w, net_h, net_w):
    if (float(net_w)/image_w) < (float(net_h)/image_h):
        new_w = net_w
        new_h = (image_h*net_w)/image_w
    else:
        new_h = net_w
        new_w = (image_w*net_h)/image_h
        
    for i in range(len(boxes)):
        x_offset, x_scale = (net_w - new_w)/2./net_w, float(new_w)/net_w
        y_offset, y_scale = (net_h - new_h)/2./net_h, float(new_h)/net_h
        
        boxes[i].xmin = int((boxes[i].xmin - x_offset) / x_scale * image_w)
        boxes[i].xmax = int((boxes[i].xmax - x_offset) / x_scale * image_w)
        boxes[i].ymin = int((boxes[i].ymin - y_offset) / y_scale * image_h)
        boxes[i].ymax = int((boxes[i].ymax - y_offset) / y_scale * image_h)

# %%
# suppress non-maximal boxes
#do_nms(boxes, 0.5)

# %%
from matplotlib.patches import Rectangle
def draw_boxes(filename, v_boxes, v_labels, v_scores):
    # load the image
    data = plt.imread(filename)
    # plot the image
    plt.imshow(data)
    # get the context for drawing boxes
    ax = plt.gca()
    # plot each box
    for i in range(len(v_boxes)):
        box = v_boxes[i]
        # get coordinates
        y1, x1, y2, x2 = box.ymin, box.xmin, box.ymax, box.xmax
        # calculate width and height of the box
        width, height = x2 - x1, y2 - y1
        # create the shape
        rect = Rectangle((x1, y1), width, height, fill=False, color='green')
        # draw the box
        ax.add_patch(rect)
        # draw text and score in top left corner
        label = "%s (%.3f)" % (v_labels[i], v_scores[i])
        plt.text(x1, y1, label, color='red')
    # show the plot
    plt.show()

# %%
# get all of the results above a threshold
# takes the list of boxes, known labels, 
#and our classification threshold as arguments and returns parallel lists of boxes, labels, and scores.
def get_boxes(boxes, labels, thresh):
    v_boxes, v_labels, v_scores = list(), list(), list()
    # enumerate all boxes
    for box in boxes:
        # enumerate all possible labels
        for i in range(len(labels)):
            # check if the threshold for this label is high enough
            if box.classes[i] > thresh:
                v_boxes.append(box)
                v_labels.append(labels[i])
                v_scores.append(box.classes[i]*100)
                # don't break, many labels may trigger for one box
    return v_boxes, v_labels, v_scores

# %%
# define the expected input shape for the model
input_w, input_h = 416, 416
# define our new photo
photo_filename = 'photo-1533090368676-1fd25485db88'
# load and prepare image
image, image_w, image_h = load_image_pixels(photo_filename, (input_w, input_h))


# make prediction
yolos = yolov3.predict(image)
# summarize the shape of the list of arrays
print([a.shape for a in yolos])

# define the anchors
anchors = [[116,90, 156,198, 373,326], [30,61, 62,45, 59,119], [10,13, 16,30, 33,23]]
# define the probability threshold for detected objects
class_threshold = 0.6
boxes = list()

for i in range(len(yolos)):
        # decode the output of the network
    boxes += decode_netout(yolos[i][0], anchors[i], obj_thresh,  net_h, net_w)

    # correct the sizes of the bounding boxes
correct_yolo_boxes(boxes, image_h, image_w, net_h, net_w)

# suppress non-maximal boxes
do_nms(boxes, nms_thresh)

# get the details of the detected objects
v_boxes, v_labels, v_scores = get_boxes(boxes, labels, class_threshold)
# summarize what we found
for i in range(len(v_boxes)):
    print(v_labels[i], v_scores[i])
# draw what we found
draw_boxes(photo_filename, v_boxes, v_labels, v_scores)
# Out:
# 1/1 [==============================] - 0s 32ms/step
# [(1, 13, 13, 255), (1, 26, 26, 255), (1, 52, 52, 255)]
# clock 99.20814037322998
# pottedplant 62.52347230911255
# vase 69.59816813468933
# book 79.70596551895142
# book 91.47680997848511
# book 86.35025024414062
# book 77.24019289016724
# book 82.4820339679718

# %%
# !pip install google-api-python-client
v_boxes, v_labels, v_scores = get_boxes(boxes, labels, class_threshold)
s=""
for x in v_labels:
   s+=x+" and " 
  

print(s)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.8/dist-packages (1.12.11)
# Requirement already satisfied: google-auth<3dev,>=1.16.0 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client) (2.15.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client) (3.0.1)
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client) (2.8.2)
# Requirement already satisfied: six<2dev,>=1.13.0 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client) (1.15.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client) (0.0.4)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client) (0.17.4)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.8/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client) (2.23.0)
# Requirement already satisfied: protobuf<5.0.0dev,>=3.15.0 in /usr/local/lib/python3.8/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client) (3.19.6)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client) (1.57.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client) (5.2.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3dev,>=1.16.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client) (2.10)
# clock and pottedplant and vase and book and book and book and book and book and

# %%
from googleapiclient.discovery import build
import pprint
my_api_key = "AIzaSyBrW-rmttbBmp5u3c3aseSE5NXRyhci6Xk" #The API_KEY you acquired
my_cse_id = "70f07961073cc41d2" #The search-engine-ID you created


def google_search(search_term, api_key, cse_id, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
    return res['items']

results = google_search(s, my_api_key, my_cse_id, num=10)
for result in results:
    pprint.pprint(result)
# Out:
# {'cacheId': 'K0BNV35TlGsJ',
#  'displayLink': 'www.wayfair.com',
#  'formattedUrl': 'https://www.wayfair.com/.../union-rustic-soho-wood-side-table-modern-side- '
#                  'tables-for-small-spaces-3-leg-end-table-accent-table-as-nightstand-coffee- '
#                  '...',
#  'htmlFormattedUrl': 'https://www.wayfair.com/.../union-rustic-soho-wood-side-table-modern-side- '
#                      'tables-for-small-spaces-3-leg-end-table-accent-table-as-nightstand-coffee- '
#                      '...',
#  'htmlSnippet': '... dining room, balcony or office to display a nice '
#                 '<b>potted plant</b>, candles, a <b>vase</b>, photo frame, '
#                 '<b>clock</b> or your <b>books and</b> a coffee mug while you '
#                 'read.',
#  'htmlTitle': 'Union Rustic Entiat 16&#39;&#39; Tall Solid Wood Frame End '
#               'Table Set | Wayfair',
#  'kind': 'customsearch#result',
#  'link': 'https://www.wayfair.com/furniture/pdp/union-rustic-soho-wood-side-table-modern-side-tables-for-small-spaces-3-leg-end-table-accent-table-as-nightstand-coffee-table-for-plant-in-bedroom-living-room-16-tall-12-diameter-w004996392.html',
#  'pagemap': {'cse_image': [{'src': 'https://secure.img1-fg.wfcdn.com/im/36260693/resize-h600-w600%5Ecompr-r85/1425/142589306/Entiat+16%27%27+Tall+Solid+Wood+Frame+End+Table+Set.jpg'}],
#              'cse_thumbnail': [{'height': '225',
#                                 'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcRpxogpba6e9SUtACl5sn2WcrFRQDlhM-j0nb8KHvCExOwTfe15e2BLr_o',
#                                 'width': '225'}],
#              'metatags': [{'fb:app_id': '158742637545893',
#                            'format-detection': 'telephone=no',
#                            'og:description': 'This cute side table has a mango '
#                                              'wood circular top and metal '
#                                              'black legs made of aluminum. '
#                                              'Place this in your living room, '
#                                              'dining room, balcony or office '
#                                              'to display a nice potted plant, '
#                                              'candles, a vase, photo frame, '
#                                              'clock or your books and a coffee '
#                                              'mug while you read. At an event, '
#                                              'use this handy wooden table for '
#                                              'guests to place their drinks and '
#                                              'snacks. This table pairs well '
#                                              'with both modern and '
#                                              'contemporary decor themes owing '
#                                              'to its simple circle shape and '
#                                              'clean look. The three-legged '
#                                              'sturdy yet space saving table '
#                                              'stands 16-inches tall and has a '
#                                              '12-inch diameter and needs to be '
#                                              'assembled by customer. Sold '
#                                              'individually. Union Rustic '
#                                              'encourages easy DIY decorating '
#                                              'and we hope this table will be a '
#                                              'great addition to your decor!',
#                            'og:image': 'https://secure.img1-fg.wfcdn.com/im/36260693/resize-h600-w600%5Ecompr-r85/1425/142589306/Entiat+16%27%27+Tall+Solid+Wood+Frame+End+Table+Set.jpg',
#                            'og:site_name': 'Wayfair',
#                            'og:title': "Entiat 16'' Tall Solid Wood Frame End "
#                                        'Table Set',
#                            'og:type': 'wayfairus:product',
#                            'og:upc': 'W004996392',
#                            'og:url': 'https://www.wayfair.com/furniture/pdp/union-rustic-soho-wood-side-table-modern-side-tables-for-small-spaces-3-leg-end-table-accent-table-as-nightstand-coffee-table-for-plant-in-bedroom-living-room-16-tall-12-diameter-w004996392.html',
#                            'pin:url': 'https://www.wayfair.com/furniture/pdp/union-rustic-soho-wood-side-table-modern-side-tables-for-small-spaces-3-leg-end-table-accent-table-as-nightstand-coffee-table-for-plant-in-bedroom-living-room-16-tall-12-diameter-w004996392.html',
#                            'product:price:amount': '88.99',
#                            'product:price:currency': 'USD',
#                            'referrer': 'no-referrer-when-downgrade',
#                            'twitter:card': 'summary_large_image',
#                            'twitter:description': 'This cute side table has a '
#                                                   'mango wood circular top and '
#                                                   'metal black legs made of '
#                                                   'aluminum. Place this in '
#                                                   'your living room, dining '
#                                                   'room, balcony or office to '
#                                                   'display a nice potted '
#                                                   'plant, candles, a vase, '
#                                                   'photo frame, clock or your '
#                                                   'books and a coffee mug '
#                                                   'while you read. At an '
#                                                   'event, use this handy '
#                                                   'wooden table for guests to '
#                                                   'place their drinks and '
#                                                   'snacks. This table pairs '
#                                                   'well with both modern and '
#                                                   'contemporary decor themes '
#                                                   'owing to its simple circle '
#                                                   'shape and clean look. The '
#                                                   'three-legged sturdy yet '
#                                                   'space saving table stands '
#                                                   '16-inches tall and has a '
#                                                   '12-inch diameter and needs '
#                                                   'to be assembled by '
#                                                   'customer. Sold '
#                                                   'individually. Union Rustic '
#                                                   'encourages easy DIY '
#                                                   'decorating and we hope this '
#                                                   'table will be a great '
#                                                   'addition to your decor!',
#                            'twitter:image': 'https://secure.img1-fg.wfcdn.com/im/36260693/resize-h600-w600%5Ecompr-r85/1425/142589306/Entiat+16%27%27+Tall+Solid+Wood+Frame+End+Table+Set.jpg',
#                            'twitter:title': "Entiat 16'' Tall Solid Wood Frame "
#                                             'End Table Set',
#                            'viewport': 'initial-scale=1.0, maximum-scale=5.0, '
#                                        'width=device-width'}],
#              'sitenavigationelement': [{'name': 'Departments',
#                                         'url': 'Furniture'}]},
#  'snippet': '... dining room, balcony or office to display a nice potted '
#             'plant, candles, a vase, photo frame, clock or your books and a '
#             'coffee mug while you read.',
#  'title': "Union Rustic Entiat 16'' Tall Solid Wood Frame End Table Set | "
#           'Wayfair'}
# {'cacheId': 'ZoA-N4Bg9YAJ',
#  'displayLink': 'vision.cs.utexas.edu',
#  'formattedUrl': 'https://vision.cs.utexas.edu/review/review_chair.html',
#  'htmlFormattedUrl': 'https://vision.cs.utexas.edu/review/review_chair.html',
#  'htmlSnippet': 'door chair pillow tray paper pen glass remote teepai toy '
#                 '<b>book book</b> clothes sofa ... table chair chair chair '
#                 'chair clothes woodenthings <b>pottedplant</b> frame&nbsp;...',
#  'htmlTitle': 'Untitled',
#  'kind': 'customsearch#result',
#  'link': 'https://vision.cs.utexas.edu/review/review_chair.html',
#  'pagemap': {'cse_image': [{'src': 'http://vision.cs.utexas.edu/voc/VOC2007_test/JPEGImages/003600.jpg'}],
#              'cse_thumbnail': [{'height': '198',
#                                 'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQACXJzxUlZEkJDFXPqFYYVWqHZlK8sTo-Fgrm-YbE8D6a6b7ptyA4IgoQP',
#                                 'width': '254'}]},
#  'snippet': 'door chair pillow tray paper pen glass remote teepai toy book '
#             'book clothes sofa ... table chair chair chair chair clothes '
#             'woodenthings pottedplant frame\xa0...',
#  'title': 'Untitled'}
# {'cacheId': 'jK-O7adEbToJ',
#  'displayLink': 'www.alamy.com',
#  'formattedUrl': 'https://www.alamy.com/bookshelf-with-potted-plant-books-in-cartoon-style- '
#                  'vector-illustration-isolated-on-white-background-image403649094.html',
#  'htmlFormattedUrl': 'https://www.alamy.com/<b>books</b>helf-with-<b>potted-plant</b>-<b>books</b>-in-cartoon-style- '
#                      'vector-illustration-isolated-on-white-background-image403649094.html',
#  'htmlSnippet': 'Potted plants and <b>books</b> on the shelf illustration in '
#                 'minimal style isolated on ... Bookshelf with <b>books and</b> '
#                 'potted houseplant, <b>vase</b> and wall <b>clock</b> in '
#                 'doodle.',
#  'htmlTitle': 'Bookshelf with <b>potted plant</b>. <b>Books</b> in cartoon '
#               'style. Vector illustration ...',
#  'kind': 'customsearch#result',
#  'link': 'https://www.alamy.com/bookshelf-with-potted-plant-books-in-cartoon-style-vector-illustration-isolated-on-white-background-image403649094.html',
#  'pagemap': {'cse_image': [{'src': 'https://c8.alamy.com/comp/2ECKPF2/bookshelf-with-potted-plant-books-in-cartoon-style-vector-illustration-isolated-on-white-background-2ECKPF2.jpg'}],
#              'cse_thumbnail': [{'height': '192',
#                                 'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRZpUhe9VBtRem9EkM7jblnC9E1dFewNUZyKT62aOWblj5DvCFj2JL4VYM',
#                                 'width': '262'}],
#              'metatags': [{'apple-mobile-web-app-title': 'Alamy images',
#                            'application-name': 'Alamy images',
#                            'author': 'Alamy Limited',
#                            'copyright': '© 2022 Alamy Limited',
#                            'fb:admins': '150454471633963',
#                            'msapplication-tilecolor': '#d6d6da',
#                            'next-head-count': '48',
#                            'og:description': 'Download this stock vector: '
#                                              'Bookshelf with potted plant. '
#                                              'Books in cartoon style. Vector '
#                                              'illustration isolated on white '
#                                              'background - 2ECKPF2 from '
#                                              "Alamy's library of millions of "
#                                              'high resolution stock photos, '
#                                              'illustrations and vectors.',
#                            'og:image': 'https://c8.alamy.com/comp/2ECKPF2/bookshelf-with-potted-plant-books-in-cartoon-style-vector-illustration-isolated-on-white-background-2ECKPF2.jpg',
#                            'og:title': 'Bookshelf with potted plant. Books in '
#                                        'cartoon style. Vector illustration '
#                                        'isolated on white background Stock '
#                                        'Vector Image & Art - Alamy',
#                            'og:url': 'https://www.alamy.com/bookshelf-with-potted-plant-books-in-cartoon-style-vector-illustration-isolated-on-white-background-image403649094.html',
#                            'theme-color': '#ffffff',
#                            'twitter:card': 'photo',
#                            'twitter:description': 'Download this stock vector: '
#                                                   'Bookshelf with potted '
#                                                   'plant. Books in cartoon '
#                                                   'style. Vector illustration '
#                                                   'isolated on white '
#                                                   'background - 2ECKPF2 from '
#                                                   "Alamy's library of millions "
#                                                   'of high resolution stock '
#                                                   'photos, illustrations and '
#                                                   'vectors.',
#                            'twitter:image': 'https://c8.alamy.com/comp/2ECKPF2/bookshelf-with-potted-plant-books-in-cartoon-style-vector-illustration-isolated-on-white-background-2ECKPF2.jpg',
#                            'twitter:title': 'Bookshelf with potted plant. '
#                                             'Books in cartoon style. Vector '
#                                             'illustration isolated on white '
#                                             'background Stock Vector Image & '
#                                             'Art - Alamy',
#                            'twitter:url': 'https://www.alamy.com/bookshelf-with-potted-plant-books-in-cartoon-style-vector-illustration-isolated-on-white-background-image403649094.html',
#                            'viewport': 'width=device-width, '
#                                        'initial-scale=1,maximum-scale=5'}]},
#  'snippet': 'Potted plants and books on the shelf illustration in minimal '
#             'style isolated on ... Bookshelf with books and potted houseplant, '
#             'vase and wall clock in doodle.',
#  'title': 'Bookshelf with potted plant. Books in cartoon style. Vector '
#           'illustration ...'}
# {'cacheId': 'MBL0OGzgNnwJ',
#  'displayLink': 'www.vecteezy.com',
#  'formattedUrl': 'https://www.vecteezy.com/free-vector/book-shelf',
#  'htmlFormattedUrl': 'https://www.vecteezy.com/free-vector/<b>book</b>-shelf',
#  'htmlSnippet': 'Browse 3793 incredible <b>Book</b> Shelf vectors, icons, '
#                 'clipart graphics, and backgrounds for royalty-free download '
#                 'from the creative contributors at Vecteezy!',
#  'htmlTitle': '<b>Book</b> Shelf Vector Art, Icons, and Graphics for Free '
#               'Download',
#  'kind': 'customsearch#result',
#  'link': 'https://www.vecteezy.com/free-vector/book-shelf',
#  'pagemap': {'cse_image': [{'src': 'https://static.vecteezy.com/system/resources/previews/003/069/636/original/bookshelf-in-library-room-office-shelf-wall-interior-bookshelf-free-vector.jpg'}],
#              'cse_thumbnail': [{'height': '225',
#                                 'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSTjfUs7O3clTNaKKfhMduKyXuN0PPNphLo0AaS9h0aSybv3aa7gdyASSsb',
#                                 'width': '225'}],
#              'metatags': [{'analytics_data': '{"user_status_start":"new","user_status_updated":"","user_plan":"","user_survey":"","free_download_count":0,"purchase_count":0,"ltv":0,"split_test":"pro_toast_alt_1:ignore","test_block":6,"team_owner_email":null,"team_seats":0,"multiple_logins":0,"snowplow_collector":"a.vecteezy.com","snowplow_app_id":"vecteezy_production","billing_country":null,"cloudflare_country":"US","environment":"Live","last_search_terms":"book-shelf","last_show_page":null,"last_show_content_type":null,"last_show_resource_type":null,"locale":"en","name":null,"first_name":null,"last_name":null,"page_type":"Grid","pageview_guid":"b70c1106-b54c-4e18-9fcb-a305612978c3","postal_code":null,"session_guid":"1a096eec-10c2-42bd-8076-9597c48420c1","sign_in_type":null,"feature_flags":"refer_a_friend,custom_design_service,fraud_rate_limits,fraud_acct_sharing,remove_mobile_ad_scripts"}',
#                            'csrf-param': 'authenticity_token',
#                            'csrf-token': 'umky2i5qFcy1uCvJbZDRqrE8mTKG6TIPhpL/OoICP1A6UZ4GhaMvvipOb1qhzBw64jJz9hMss/V/LPpMByEw0Q==',
#                            'msapplication-tilecolor': '#ff7900',
#                            'og:description': 'Browse 3,793 incredible Book '
#                                              'Shelf vectors, icons, clipart '
#                                              'graphics, and backgrounds for '
#                                              'royalty-free download from the '
#                                              'creative contributors at '
#                                              'Vecteezy!',
#                            'og:image': 'https://static.vecteezy.com/system/resources/previews/003/069/636/original/bookshelf-in-library-room-office-shelf-wall-interior-bookshelf-free-vector.jpg',
#                            'og:locale': 'en_US',
#                            'og:locale:alternate': 'de_DE',
#                            'og:site_name': 'Vecteezy',
#                            'og:title': 'Download Free Vectors, Clipart '
#                                        'Graphics, Vector Art & Design '
#                                        'Templates',
#                            'og:type': 'website',
#                            'og:url': 'https://www.vecteezy.com/free-vector/book-shelf',
#                            'theme-color': '#ff7900',
#                            'turbolinks-cache-control': 'no-cache',
#                            'twitter:card': 'summary_large_image',
#                            'twitter:creator': '@Vecteezy',
#                            'twitter:site': '@Vecteezy',
#                            'viewport': 'width=device-width, initial-scale=1.0, '
#                                        'minimum-scale=1.0'}]},
#  'snippet': 'Browse 3793 incredible Book Shelf vectors, icons, clipart '
#             'graphics, and backgrounds for royalty-free download from the '
#             'creative contributors at Vecteezy!',
#  'title': 'Book Shelf Vector Art, Icons, and Graphics for Free Download'}
# {'cacheId': 'OVGAuQexFZ8J',
#  'displayLink': 'www.alamy.com',
#  'formattedUrl': 'https://www.alamy.com/stock-photo/book-shelf-home-neat.html',
#  'htmlFormattedUrl': 'https://www.alamy.com/stock-photo/<b>book</b>-shelf-home-neat.html',
#  'htmlSnippet': 'encyclopedia <b>books</b>, plant and alarm <b>clock</b> on '
#                 'white shelf - organized concept Stock ... by <b>potted '
#                 'plant</b>, stationary in glass <b>vase and book</b> shelf '
#                 'over com.',
#  'htmlTitle': '<b>Book</b> shelf home neat hi-res stock photography and images '
#               '- Alamy',
#  'kind': 'customsearch#result',
#  'link': 'https://www.alamy.com/stock-photo/book-shelf-home-neat.html',
#  'pagemap': {'cse_image': [{'src': 'https://c8.alamy.com/comp/2HFC21X/porto-portugal-18-nov-2020-a-variety-of-books-stacked-neat-and-tidy-on-a-wooden-book-shelf-in-a-book-store-or-library-organisation-concept-2HFC21X.jpg'}],
#              'cse_thumbnail': [{'height': '192',
#                                 'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcQX3pDesnPikg5Eq52uNLU-_zpc38fH8f_V6uctfyXOFPg1MlzM6iRX3YQ',
#                                 'width': '262'}],
#              'metatags': [{'apple-mobile-web-app-title': 'Alamy images',
#                            'application-name': 'Alamy images',
#                            'author': 'Alamy Limited',
#                            'copyright': '© 2022 Alamy Limited',
#                            'fb:admins': '150454471633963',
#                            'msapplication-tilecolor': '#d6d6da',
#                            'next-head-count': '135',
#                            'og:description': 'Find the perfect book shelf home '
#                                              'neat stock photo, image, vector, '
#                                              'illustration or 360 image. '
#                                              'Available for both RF and RM '
#                                              'licensing.',
#                            'og:image': 'https://c8.alamy.com/comp/2HFC21X/porto-portugal-18-nov-2020-a-variety-of-books-stacked-neat-and-tidy-on-a-wooden-book-shelf-in-a-book-store-or-library-organisation-concept-2HFC21X.jpg',
#                            'og:image:alt': 'Book shelf home neat Stock Photos '
#                                            'and Images',
#                            'og:site_name': 'Alamy',
#                            'og:title': 'Book shelf home neat hi-res stock '
#                                        'photography and images - Alamy',
#                            'og:type': 'website',
#                            'og:url': 'https://www.alamy.com/stock-photo/book-shelf-home-neat.html',
#                            'theme-color': '#ffffff',
#                            'twitter:card': 'summary_large_image',
#                            'twitter:description': 'Find the perfect book shelf '
#                                                   'home neat stock photo, '
#                                                   'image, vector, illustration '
#                                                   'or 360 image. Available for '
#                                                   'both RF and RM licensing.',
#                            'twitter:image': 'https://c8.alamy.com/comp/2HFC21X/porto-portugal-18-nov-2020-a-variety-of-books-stacked-neat-and-tidy-on-a-wooden-book-shelf-in-a-book-store-or-library-organisation-concept-2HFC21X.jpg',
#                            'twitter:image:alt': 'Book shelf home neat Stock '
#                                                 'Photos and Images',
#                            'twitter:site': '@Alamy',
#                            'twitter:title': 'Book shelf home neat hi-res stock '
#                                             'photography and images - Alamy',
#                            'viewport': 'width=device-width, '
#                                        'initial-scale=1,maximum-scale=5'}]},
#  'snippet': 'encyclopedia books, plant and alarm clock on white shelf - '
#             'organized concept Stock ... by potted plant, stationary in glass '
#             'vase and book shelf over com.',
#  'title': 'Book shelf home neat hi-res stock photography and images - Alamy'}
# {'cacheId': 'zE6gchPJ8ugJ',
#  'displayLink': 'www.pinterest.com',
#  'formattedUrl': 'https://www.pinterest.com/.../green-house-plant-leaves-in-blue-planter- '
#                  'illustration-aesthetic-potted-green-plant-potted-plant-png-transparent-clipar...',
#  'htmlFormattedUrl': 'https://www.pinterest.com/.../green-house-plant-leaves-in-blue-planter- '
#                      'illustration-aesthetic-potted-green-plant-<b>potted-plant</b>-png-transparent-clipar...',
#  'htmlSnippet': '<b>Vases</b> Decor, Plant Decor, Incense Photography, <b>Book '
#                 'Clock</b>, Plants In Bottles,. Indoor Plants Hd Transparent, '
#                 'Indoor Plants Illustration Home Decoration Hand&nbsp;...',
#  'htmlTitle': 'Planter Pot Clipart Vector, Green House Plant Leaves In Blue '
#               '...',
#  'kind': 'customsearch#result',
#  'link': 'https://www.pinterest.com/pin/green-house-plant-leaves-in-blue-planter-illustration-aesthetic-potted-green-plant-potted-plant-png-transparent-clipart-image-and-psd-file-for-free-download-in-2022--254312710199513731/',
#  'pagemap': {'cse_image': [{'src': 'https://i.pinimg.com/736x/fe/e5/2b/fee52b2f327fe95dc48739d3cb5fab17.jpg'}],
#              'cse_thumbnail': [{'height': '225',
#                                 'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcScukF0XnRY11rLR2y6wJh5u2iKmxgbplZRVbpgW0BmrGGbAnWmqQs6_F0u',
#                                 'width': '225'}],
#              'metatags': [{'application-name': 'Pinterest',
#                            'fb:app_id': '274266067164',
#                            'msapplication-tilecolor': '#ffffff',
#                            'msapplication-tileimage': 'https://s.pinimg.com/webapp/logo_trans_144x144-5e37c0c6.png',
#                            'og:description': 'Feb 23, 2022 - Download this '
#                                              'Green House Plant Leaves In Blue '
#                                              'Planter Illustration Aesthetic '
#                                              'Potted, Green, Plant, Potted '
#                                              'Plant PNG clipart image with '
#                                              'transparent background for free. '
#                                              'Pngtree provides millions of '
#                                              'free png, vectors, clipart '
#                                              'images and psd graphic resources '
#                                              'for designers.| 7270769',
#                            'og:image': 'https://i.pinimg.com/736x/fe/e5/2b/fee52b2f327fe95dc48739d3cb5fab17.jpg',
#                            'og:image:height': '640',
#                            'og:image:width': '640',
#                            'og:see_also': 'https://pngtree.com/freepng/green-house-plant-leaves-in-blue-planter-illustration-aesthetic-potted_7270769.html',
#                            'og:site_name': 'Pinterest',
#                            'og:title': 'Planter Pot Clipart Vector, Green '
#                                        'House Plant Leaves In Blue Planter '
#                                        'Illustration Aesthetic Potted, Green, '
#                                        'Plant, Potted Plant PNG Image For Free '
#                                        'Download in 2022 | Blue planter, Plant '
#                                        'leaves, House plants',
#                            'og:type': 'pinterestapp:pin',
#                            'og:updated_time': '2022-02-23T06:54:44.000Z',
#                            'og:url': 'https://www.pinterest.nz/pin/planter-pot-clipart-vector-green-house-plant-leaves-in-blue-planter-illustration-aesthetic-potted-green-plant-potted-plant-png-image-for-free-download-in-2022--254312710199513731/',
#                            'pinterestapp:pinboard': 'https://www.pinterest.com/cchilaw/flowers-and-floral-hand-drawn-illustration/',
#                            'pinterestapp:pinner': 'https://www.pinterest.com/cchilaw/',
#                            'pinterestapp:repins': '0',
#                            'pinterestapp:source': 'https://pngtree.com/freepng/green-house-plant-leaves-in-blue-planter-illustration-aesthetic-potted_7270769.html',
#                            'referrer': 'origin',
#                            'twitter:description': 'Feb 23, 2022 - Download '
#                                                   'this Green House Plant '
#                                                   'Leaves In Blue Planter '
#                                                   'Illustration Aesthetic '
#                                                   'Potted, Green, Plant, '
#                                                   'Potted Plant PNG clipart '
#                                                   'image with transparent '
#                                                   'background for free. '
#                                                   'Pngtree provides millions '
#                                                   'of free png, vectors, '
#                                                   'clipart images and psd '
#                                                   'graphic resources for '
#                                                   'designers.| 7270769',
#                            'twitter:image:src': 'https://i.pinimg.com/736x/fe/e5/2b/fee52b2f327fe95dc48739d3cb5fab17.jpg',
#                            'twitter:title': 'Planter Pot Clipart Vector, Green '
#                                             'House Plant Leaves In Blue '
#                                             'Planter Illustration Aesthetic '
#                                             'Potted, Green, Plant, Potted '
#                                             'Plant PNG Image For Free Download '
#                                             'in 2022 | Blue planter, Plant '
#                                             'leaves, House plants',
#                            'viewport': 'width=device-width, initial-scale=1'}]},
#  'snippet': 'Vases Decor, Plant Decor, Incense Photography, Book Clock, Plants '
#             'In Bottles,. Indoor Plants Hd Transparent, Indoor Plants '
#             'Illustration Home Decoration Hand\xa0...',
#  'title': 'Planter Pot Clipart Vector, Green House Plant Leaves In Blue ...'}
# {'cacheId': 'f8s4Kq6bFhkJ',
#  'displayLink': 'www.shutterstock.com',
#  'formattedUrl': 'https://www.shutterstock.com/search/brick-wall-desk-notebooks',
#  'htmlFormattedUrl': 'https://www.shutterstock.com/search/brick-wall-desk-note<b>books</b>',
#  'htmlSnippet': 'An open laptop on an office desk with flower, coffee, '
#                 '<b>books</b> in front of ... Front view laptop, alarm '
#                 '<b>clock</b>, <b>books and potted plant</b> on white office '
#                 'desk.',
#  'htmlTitle': '4,245 Brick Wall Desk Notebooks Images, Stock Photos &amp; '
#               'Vectors ...',
#  'kind': 'customsearch#result',
#  'link': 'https://www.shutterstock.com/search/brick-wall-desk-notebooks',
#  'pagemap': {'cse_image': [{'src': 'https://www.shutterstock.com/shutterstock/photos/1167670606/display_1500/stock-photo-mockup-workspace-vintage-books-dry-flower-office-stationery-and-cork-frame-over-red-brick-wall-1167670606.jpg'}],
#              'cse_thumbnail': [{'height': '192',
#                                 'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcTo-HFHFpJHhrcKyQbYHVRVRk3XWCxruPdRVbnuiR8KFEc2yhq28dCkV7k',
#                                 'width': '262'}],
#              'metatags': [{'apple-itunes-app': 'app-id=473347409, '
#                                                'app-argument=http://www.shutterstock.com/',
#                            'next-head-count': '30',
#                            'og:description': 'Find Brick wall desk notebooks '
#                                              'stock images in HD and millions '
#                                              'of other royalty-free stock '
#                                              'photos, illustrations and '
#                                              'vectors in the Shutterstock '
#                                              'collection.  Thousands of new, '
#                                              'high-quality pictures added '
#                                              'every day.',
#                            'og:image': 'https://www.shutterstock.com/shutterstock/photos/1167670606/display_1500/stock-photo-mockup-workspace-vintage-books-dry-flower-office-stationery-and-cork-frame-over-red-brick-wall-1167670606.jpg',
#                            'og:image:height': '1000',
#                            'og:image:width': '1500',
#                            'og:site_name': 'Shutterstock',
#                            'og:title': '4,245 Brick Wall Desk Notebooks '
#                                        'Images, Stock Photos & Vectors | '
#                                        'Shutterstock',
#                            'og:ttl': '604800',
#                            'og:type': 'website',
#                            'og:url': 'https://www.shutterstock.com/search/brick-wall-desk-notebooks',
#                            'twitter:card': 'summary_large_image',
#                            'twitter:site': '@shutterstock',
#                            'viewport': 'minimum-scale=1, initial-scale=1, '
#                                        'width=device-width'}]},
#  'snippet': 'An open laptop on an office desk with flower, coffee, books in '
#             'front of ... Front view laptop, alarm clock, books and potted '
#             'plant on white office desk.',
#  'title': '4,245 Brick Wall Desk Notebooks Images, Stock Photos & Vectors ...'}
# {'cacheId': 'ceZdeHm8248J',
#  'displayLink': '3dscenegraph.stanford.edu',
#  'fileFormat': 'PDF/Adobe Acrobat',
#  'formattedUrl': 'https://3dscenegraph.stanford.edu/images/supp_mat.pdf',
#  'htmlFormattedUrl': 'https://3dscenegraph.stanford.edu/images/supp_mat.pdf',
#  'htmlSnippet': 'nearest objects of <b>clock potted plant</b>. 30% chair. 13% '
#                 '<b>book</b>. 12% <b>vase</b>. 12% dining table. 9% bed. 6% '
#                 '<b>clock</b>. 4% etc. 13% nearest objects of couch.',
#  'htmlTitle': 'A Structure for Unified Semantics, 3D Space, and ... - 3D Scene '
#               'Graph',
#  'kind': 'customsearch#result',
#  'link': 'https://3dscenegraph.stanford.edu/images/supp_mat.pdf',
#  'mime': 'application/pdf',
#  'pagemap': {'metatags': [{'creationdate': 'D:20191015205556Z',
#                            'creator': 'LaTeX with hyperref package',
#                            'fullbanner': 'This is pdfTeX, Version '
#                                          '3.14159265-2.6-1.40.18 (TeX Live '
#                                          '2017) kpathsea version 6.2.3',
#                            'moddate': 'D:20191015205556Z',
#                            'producer': 'pdfTeX-1.40.18'}]},
#  'snippet': 'nearest objects of clock potted plant. 30% chair. 13% book. 12% '
#             'vase. 12% dining table. 9% bed. 6% clock. 4% etc. 13% nearest '
#             'objects of couch.',
#  'title': 'A Structure for Unified Semantics, 3D Space, and ... - 3D Scene '
#           'Graph'}
# {'cacheId': 'OgGOgls9FXsJ',
#  'displayLink': 'unsplash.com',
#  'formattedUrl': 'https://unsplash.com/photos/h3fqTN2LMhU',
#  'htmlFormattedUrl': 'https://unsplash.com/photos/h3fqTN2LMhU',
#  'htmlSnippet': 'May 15, 2020 <b>...</b> <b>books</b> on the table. Browse '
#                 'premium related images on iStock | Save 20% with code '
#                 'UNSPLASH20. View more on iStock ↗. Related tags.',
#  'htmlTitle': 'white and purple flowers in blue <b>vase</b> beside blue and '
#               'silver bell ...',
#  'kind': 'customsearch#result',
#  'link': 'https://unsplash.com/photos/h3fqTN2LMhU',
#  'pagemap': {'cse_image': [{'src': 'https://media.istockphoto.com/id/1339386889/photo/collection-of-various-succulent-plants-in-white-pots-potted-cactus-house-plants-on-white.jpg?s=170667a&w=0&k=20&c=KL6RTT97is1R1_pnN5fmK4DlWfszzy2ko1dvewAskt4='}],
#              'cse_thumbnail': [{'height': '183',
#                                 'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcT-20vNi9Lj3AxIGFlYUFStNazCyHWZrRQMH4kwF4Q3vhEGaf1YpQ_c1vH6',
#                                 'width': '275'}],
#              'imageobject': [{'contenturl': 'https://unsplash.com/photos/caLZjNiAHrU',
#                               'thumbnailurl': 'https://images.unsplash.com/photo-1563261883-25b59aad64d8?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1yZWxhdGVkfDF8fHxlbnwwfHx8fA%3D%3D&w=1000&q=80'},
#                              {'contenturl': 'https://unsplash.com/photos/S_ncR5Q41PI',
#                               'thumbnailurl': 'https://images.unsplash.com/photo-1529113241001-b495badd8d44?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1yZWxhdGVkfDR8fHxlbnwwfHx8fA%3D%3D&w=1000&q=80'},
#                              {'contenturl': 'https://unsplash.com/photos/8ioenvmof-I',
#                               'thumbnailurl': 'https://images.unsplash.com/photo-1466781783364-36c955e42a7f?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1yZWxhdGVkfDd8fHxlbnwwfHx8fA%3D%3D&w=1000&q=80'},
#                              {'contenturl': 'https://unsplash.com/photos/cpEO3HoKdKM',
#                               'thumbnailurl': 'https://images.unsplash.com/photo-1468174482686-1047396f13b3?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1yZWxhdGVkfDl8fHxlbnwwfHx8fA%3D%3D&w=1000&q=80'},
#                              {'contenturl': 'https://unsplash.com/photos/HBEDoPQM6jM',
#                               'thumbnailurl': 'https://images.unsplash.com/photo-1589578641895-56f5e660549f?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1yZWxhdGVkfDEwfHx8ZW58MHx8fHw%3D&w=1000&q=80'},
#                              {'contenturl': 'https://unsplash.com/photos/a0rE64YJDA4',
#                               'thumbnailurl': 'https://images.unsplash.com/photo-1581783342308-f792dbdd27c5?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1yZWxhdGVkfDExfHx8ZW58MHx8fHw%3D&w=1000&q=80'},
#                              {'contenturl': 'https://unsplash.com/photos/QMgIlcvYDvE',
#                               'thumbnailurl': 'https://images.unsplash.com/photo-1526196426814-11be562a41bc?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1yZWxhdGVkfDE0fHx8ZW58MHx8fHw%3D&w=1000&q=80'},
#                              {'contenturl': 'https://unsplash.com/photos/rbO3Cy9RfNI',
#                               'thumbnailurl': 'https://images.unsplash.com/photo-1614348531934-c338408a46bb?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1yZWxhdGVkfDE3fHx8ZW58MHx8fHw%3D&w=1000&q=80'},
#                              {'contenturl': 'https://unsplash.com/photos/m2J105CzEAU',
#                               'thumbnailurl': 'https://images.unsplash.com/photo-1471086569966-db3eebc25a59?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1yZWxhdGVkfDE5fHx8ZW58MHx8fHw%3D&w=1000&q=80'},
#                              {'contenturl': 'https://unsplash.com/photos/i8-e3LG0Z70',
#                               'thumbnailurl': 'https://images.unsplash.com/photo-1513135724701-30343e546328?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1yZWxhdGVkfDJ8fHxlbnwwfHx8fA%3D%3D&w=1000&q=80'},
#                              {'contenturl': 'https://unsplash.com/photos/0-frPETzEVs',
#                               'thumbnailurl': 'https://images.unsplash.com/photo-1490312278390-ab64016e0aa9?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1yZWxhdGVkfDN8fHxlbnwwfHx8fA%3D%3D&w=1000&q=80'},
#                              {'contenturl': 'https://unsplash.com/photos/VFs2fZEVkXo',
#                               'thumbnailurl': 'https://images.unsplash.com/photo-1516641396056-0ce60a85d49f?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1yZWxhdGVkfDV8fHxlbnwwfHx8fA%3D%3D&w=1000&q=80'},
#                              {'contenturl': 'https://unsplash.com/photos/BlIhVfXbi9s',
#                               'thumbnailurl': 'https://images.unsplash.com/photo-1533090161767-e6ffed986c88?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1yZWxhdGVkfDZ8fHxlbnwwfHx8fA%3D%3D&w=1000&q=80'},
#                              {'contenturl': 'https://unsplash.com/photos/j05zD0YtZBw',
#                               'thumbnailurl': 'https://images.unsplash.com/photo-1578934691229-08987b226b47?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1yZWxhdGVkfDh8fHxlbnwwfHx8fA%3D%3D&w=1000&q=80'},
#                              {'contenturl': 'https://unsplash.com/photos/B8qIaoeKcfU',
#                               'thumbnailurl': 'https://images.unsplash.com/photo-1564247556387-6e97f44aa0cd?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1yZWxhdGVkfDEyfHx8ZW58MHx8fHw%3D&w=1000&q=80'},
#                              {'contenturl': 'https://unsplash.com/photos/GybmMi0QZV4',
#                               'thumbnailurl': 'https://images.unsplash.com/photo-1634638415860-cef1aafb60c4?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1yZWxhdGVkfDEzfHx8ZW58MHx8fHw%3D&w=1000&q=80'},
#                              {'contenturl': 'https://unsplash.com/photos/L5JhsKIvw_U',
#                               'thumbnailurl': 'https://images.unsplash.com/photo-1577017050748-389f0021d860?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1yZWxhdGVkfDE1fHx8ZW58MHx8fHw%3D&w=1000&q=80'},
#                              {'contenturl': 'https://unsplash.com/photos/OJZB0VUQKKc',
#                               'thumbnailurl': 'https://images.unsplash.com/photo-1519682577862-22b62b24e493?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1yZWxhdGVkfDE2fHx8ZW58MHx8fHw%3D&w=1000&q=80'},
#                              {'contenturl': 'https://unsplash.com/photos/L_Zaxx0nKns',
#                               'thumbnailurl': 'https://images.unsplash.com/photo-1612620535624-f6695d4864bb?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1yZWxhdGVkfDE4fHx8ZW58MHx8fHw%3D&w=1000&q=80'},
#                              {'contenturl': 'https://unsplash.com/photos/1mPkRa-qM_U',
#                               'thumbnailurl': 'https://images.unsplash.com/photo-1514454923228-7ef54f9251c9?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1yZWxhdGVkfDIwfHx8ZW58MHx8fHw%3D&w=1000&q=80'}],
#              'metatags': [{'apple-itunes-app': 'app-id=1290631746',
#                            'apple-mobile-web-app-capable': 'yes',
#                            'apple-mobile-web-app-title': 'Unsplash',
#                            'application-name': 'Unsplash',
#                            'author': 'Unsplash',
#                            'charset': 'UTF8',
#                            'mobile-web-app-capable': 'yes',
#                            'msapplication-config': 'browserconfig.xml',
#                            'msapplication-tilecolor': '#ffffff',
#                            'msapplication-tileimage': 'https://unsplash.com/mstile-144x144.png',
#                            'og:description': 'books on the table – Download '
#                                              'this photo by Milk-Tea on '
#                                              'Unsplash',
#                            'og:image': 'https://images.unsplash.com/photo-1589578036109-592d4dadb148?crop=faces%2Cedges&cs=tinysrgb&fit=crop&fm=jpg&ixid=MnwxMjA3fDB8MXxhbGx8fHx8fHx8fHwxNjcwODc3Mjk2&ixlib=rb-4.0.3&q=60&w=1200&auto=format&h=630&mark-w=64&mark-align=top%2Cleft&mark-pad=50&blend-mode=normal&blend-alpha=10&blend-w=1&mark=https%3A%2F%2Fimages.unsplash.com%2Fopengraph%2Flogo.png&blend=000000',
#                            'og:title': 'Photo by Milk-Tea on Unsplash',
#                            'og:type': 'website',
#                            'og:url': 'https://unsplash.com/photos/h3fqTN2LMhU',
#                            'theme-color': '#ffffff',
#                            'twitter:card': 'summary_large_image',
#                            'twitter:creator': '@pureimages2020',
#                            'twitter:description': 'books on the table – '
#                                                   'Download this photo by '
#                                                   'Milk-Tea on Unsplash',
#                            'twitter:image': 'https://images.unsplash.com/photo-1589578036109-592d4dadb148?crop=faces%2Cedges&cs=tinysrgb&fit=crop&fm=jpg&ixid=MnwxMjA3fDB8MXxhbGx8fHx8fHx8fHwxNjcwODc3Mjk2&ixlib=rb-4.0.3&q=60&w=1200&auto=format&h=630&mark-w=64&mark-align=top%2Cleft&mark-pad=50&blend-mode=normal&blend-alpha=10&blend-w=1&mark=https%3A%2F%2Fimages.unsplash.com%2Fopengraph%2Flogo.png&blend=000000',
#                            'twitter:site': '@unsplash',
#                            'twitter:title': 'Photo by Milk-Tea on Unsplash',
#                            'twitter:url': 'https://unsplash.com/photos/h3fqTN2LMhU',
#                            'viewport': 'width=device-width, initial-scale=1.0, '
#                                        'minimal-ui'}]},
#  'snippet': 'May 15, 2020 ... books on the table. Browse premium related '
#             'images on iStock | Save 20% with code UNSPLASH20. View more on '
#             'iStock ↗. Related tags.',
#  'title': 'white and purple flowers in blue vase beside blue and silver bell '
#           '...'}
# {'cacheId': 'nGlfQUZ7knIJ',
#  'displayLink': 'www.architecturaldigest.com',
#  'formattedUrl': 'https://www.architecturaldigest.com/gallery/outstanding-american-gardens',
#  'htmlFormattedUrl': 'https://www.architecturaldigest.com/gallery/outstanding-american-gardens',
#  'htmlSnippet': 'Sep 24, 2015 <b>...</b> The Garden Conservancy, founded in '
#                 '1990 by the late garden-world luminary Frank Cabot, has spent '
#                 'the past 25 years championing, chronicling,&nbsp;...',
#  'htmlTitle': 'Outstanding Gardens in America Examined in New <b>Book</b> ...',
#  'kind': 'customsearch#result',
#  'link': 'https://www.architecturaldigest.com/gallery/outstanding-american-gardens',
#  'pagemap': {'cse_image': [{'src': 'https://media.architecturaldigest.com/photos/56046533880a680d617aa4b6/16:9/w_2580,c_limit/outstanding-american-gardens-01.jpg'}],
#              'cse_thumbnail': [{'height': '168',
#                                 'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRDo5SrZRPyAZotvmQU10Mj9876rMEVk5532qQ55N869m3Fck2CbJRncJ_1',
#                                 'width': '300'}],
#              'metatags': [{'article:author': 'Nick Mafi',
#                            'article:content_tier': 'free',
#                            'article:modified_time': '2015-09-24T21:22:19.323Z',
#                            'article:opinion': 'false',
#                            'article:published_time': '2015-09-24T21:22:19.323Z',
#                            'article:section': 'tags',
#                            'author': 'Condé Nast',
#                            'content-type': 'gallery',
#                            'copyright': 'Copyright (c) Condé Nast 2022',
#                            'fb:app_id': '267091300008193',
#                            'fb:pages': '43794751042',
#                            'google-signin-client_id': '960933707988-c28a5u0f04t7r9sdmr2u8ct9tioi4m1n.apps.googleusercontent.com',
#                            'id': '560465bf880a680d617aa4d9',
#                            'msapplication-tap-highlight': 'no',
#                            'news_keywords': 'daily '
#                                             'ad,architecture,design,gardens,landscape '
#                                             'architecture,landscape',
#                            'og:description': 'From Connecticut to California, '
#                                              'the best gardens in America are '
#                                              'showcased in a new book',
#                            'og:image': 'https://media.architecturaldigest.com/photos/56046533880a680d617aa4b6/16:9/w_2580,c_limit/outstanding-american-gardens-01.jpg',
#                            'og:site_name': 'Architectural Digest',
#                            'og:title': 'A New Book Examines Great American '
#                                        'Gardens',
#                            'og:type': 'article',
#                            'og:url': 'https://www.architecturaldigest.com/gallery/outstanding-american-gardens',
#                            'parsely-metadata': '{"description":"From '
#                                                'Connecticut to California, the '
#                                                'best gardens in America are '
#                                                'showcased in a new '
#                                                'book","image-16-9":"https://media.architecturaldigest.com/photos/56046533880a680d617aa4b6/16:9/w_1000,c_limit/outstanding-american-gardens-01.jpg","image-1-1":"https://media.architecturaldigest.com/photos/56046533880a680d617aa4b6/1:1/w_1000,c_limit/outstanding-american-gardens-01.jpg"}',
#                            'parsely-post-id': '560465bf880a680d617aa4d9',
#                            'referrer': 'no-referrer-when-downgrade',
#                            'twitter:card': 'summary_large_image',
#                            'twitter:creator': '@ArchDigest',
#                            'twitter:description': 'From Connecticut to '
#                                                   'California, the best '
#                                                   'gardens in America are '
#                                                   'showcased in a new book',
#                            'twitter:domain': 'https://www.architecturaldigest.com',
#                            'twitter:image': 'https://media.architecturaldigest.com/photos/56046533880a680d617aa4b6/16:9/w_2580,c_limit/outstanding-american-gardens-01.jpg?mbid=social_retweet',
#                            'twitter:site': '@ArchDigest',
#                            'twitter:title': 'A New Book Examines Great '
#                                             'American Gardens',
#                            'viewport': 'width=device-width, initial-scale=1'}]},
#  'snippet': 'Sep 24, 2015 ... The Garden Conservancy, founded in 1990 by the '
#             'late garden-world luminary Frank Cabot, has spent the past 25 '
#             'years championing, chronicling,\xa0...',
#  'title': 'Outstanding Gardens in America Examined in New Book ...'}

# %%
# search to get the search results
